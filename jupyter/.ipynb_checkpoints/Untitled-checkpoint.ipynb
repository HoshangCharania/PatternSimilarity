# %%
import json,urllib.request
import pandas as pd
from scipy.stats import zscore
from scipy.spatial.distance import euclidean
from fastdtw import fastdtw
from scipy.fftpack import fft, ifft
from saxpy import sax
from saxpy.sax import sax_via_window
from scipy import spatial
from sklearn.metrics.pairwise import cosine_similarity
import numpy

# %%
stockSymbol="MSFT"
print(data)
data = urllib.request.urlopen("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=",stockSymbol,"&outputsize=full&apikey=GZ78DWYK4UQOVQ83").read()
output = json.loads(data)
jsonOutput=output["Time Series (Daily)"]
dF_Daily=pd.DataFrame.from_dict(jsonOutput, orient="index")
dF_Daily.index=pd.to_datetime(dF_Daily.index)
# Out:
# MSFT
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-357f4985458a> in <module>()
#       1 stockSymbol="MSFT"
#       2 print(stockSymbol)
# ----> 3 data = urllib.request.urlopen("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=",stockSymbol,"&outputsize=full&apikey=GZ78DWYK4UQOVQ83").read()
#       4 output = json.loads(data)
#       5 jsonOutput=output["Time Series (Daily)"]
#
# /anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     522         for processor in self.process_request.get(protocol, []):
#     523             meth = getattr(processor, meth_name)
# --> 524             req = meth(req)
#     525
#     526         response = self._open(req, data)
#
# /anaconda3/lib/python3.6/urllib/request.py in do_request_(self, request)
#    1246                 msg = "POST data should be bytes, an iterable of bytes, " \
#    1247                       "or a file object. It cannot be of type str."
# -> 1248                 raise TypeError(msg)
#    1249             if not request.has_header('Content-type'):
#    1250                 request.add_unredirected_header(
#
# TypeError: POST data should be bytes, an iterable of bytes, or a file object. It cannot be of type str.

# %%
dataframes=[];
for x in range(1998,2018):
    dataframes.append(dF_Daily[dF_Daily.index.year == x])
min=365;
for x in range(0,len(dataframes)):
    if(len(dataframes[x])<min):
        min=len(dataframes[x])
combinedYearsDataFrame=pd.DataFrame();
for x in range(0,len(dataframes)):
    dataframes[x]=dataframes[x][:min]
    #print(dataframes[x])
    dataframe = [ float(x) for x in list(dataframes[x]["1. open"]) ]
    combinedYearsDataFrame[1998+x]=dataframe

# %% [markdown]
# ## DTW

# %%
for x in range(1998,2018):
    combinedYearsDataFrame[x]=zscore(combinedYearsDataFrame[x])


#Keeping a threshold of -3 and +3 for a +! and others for a -1
pathDict={};
for x in range(1998,2018):
    for y in range(x, 2018):
        distance, path = fastdtw(combinedYearsDataFrame[x], combinedYearsDataFrame[y], dist=euclidean)
        #print(distance)
        score=0
        for z in range(0,len(path)):
            #print(path[z][1])
            if((path[z][0]-path[z][1]<=15) &(path[z][0]-path[z][1]>=-15)):
                score=score+1;
            else:
                score=score-1;
        pathDict[x,y]=score

# %%
pathDict
# Out:
# {(1998, 1998): 248,
#  (1998, 1999): 72,
#  (1998, 2000): 22,
#  (1998, 2001): 74,
#  (1998, 2002): -261,
#  (1998, 2003): -53,
#  (1998, 2004): 103,
#  (1998, 2005): 33,
#  (1998, 2006): -241,
#  (1998, 2007): -110,
#  (1998, 2008): -89,
#  (1998, 2009): -135,
#  (1998, 2010): -303,
#  (1998, 2011): 170,
#  (1998, 2012): -30,
#  (1998, 2013): -56,
#  (2005, 2007): -37,
#  (2005, 2008): -37,
#  (2005, 2009): -18,
#  (2005, 2010): -350,
#  (2005, 2011): -257,
#  (2005, 2012): -129,
#  (2005, 2013): -31,
#  (2005, 2014): -87,
#  (2005, 2015): -74,
#  (2005, 2016): -60,
#  (2005, 2017): -154,
#  (2006, 2006): 248,
#  (2006, 2007): -134,
#  (2006, 2008): -227,
#  (2006, 2009): -183,
#  (2006, 2010): -217,
#  (2006, 2011): 135,
#  (2006, 2012): 8,
#  (2006, 2013): -49,
#  (2006, 2014): -103,
#  (2006, 2015): -193,
#  (2006, 2016): 43,
#  (2006, 2017): -166,
#  (2007, 2007): 248,
#  (2007, 2008): -201,
#  (2007, 2009): -12,
#  (2007, 2010): -313,
#  (2007, 2011): -141,
#  (2007, 2012): -94,
#  (2007, 2013): 118,
#  (2007, 2014): 34,
#  (2007, 2015): 323,
#  (2007, 2016): -207,
#  (2007, 2017): 21,
#  (2008, 2008): 248,
#  (2008, 2009): 132,
#  (2008, 2010): -56,
#  (2008, 2011): -104,
#  (2008, 2012): 75,
#  (2008, 2013): 89,
#  (2008, 2014): 202,
#  (2008, 2015): 62,
#  (2008, 2016): 132,
#  (2008, 2017): 182,
#  (2009, 2009): 248,
#  (2009, 2010): -328,
#  (2009, 2011): -188,
#  (2009, 2012): -110,
#  (2009, 2013): 87,
#  (2009, 2014): 118,
#  (2009, 2015): 14,
#  (2009, 2016): -43,
#  (2009, 2017): 83,
#  (2010, 2010): 248,
#  (2010, 2011): -248,
#  (2010, 2012): -53,
#  (2010, 2013): -235,
#  (2010, 2014): -200,
#  (2010, 2015): -328,
#  (2010, 2016): -157,
#  (2010, 2017): -202,
#  (2011, 2011): 248,
#  (2011, 2012): -116,
#  (2011, 2013): 84,
#  (2011, 2014): -1,
#  (2011, 2015): -158,
#  (2011, 2016): 29,
#  (2011, 2017): 37,
#  (2012, 2012): 248,
#  (2012, 2013): -175,
#  (2012, 2014): -239,
#  (2012, 2015): -57,
#  (2012, 2016): -193,
#  (2012, 2017): -208,
#  (2013, 2013): 248,
#  (2013, 2014): -7,
#  (2013, 2015): 137,
#  (2013, 2016): -7,
#  (2013, 2017): 20,
#  (2014, 2014): 248,
#  (2014, 2015): 16,
#  (2014, 2016): 148,
#  (2014, 2017): 123,
#  (2015, 2015): 248,
#  (2015, 2016): -103,
#  (2015, 2017): -17,
#  (2016, 2016): 248,
#  (2016, 2017): 16,
#  (2017, 2017): 248}

# %% [markdown]
# ## Symbolic Aggregate approXimation

# %%
# All tests will be run with 6 letter words
# and 5 letter alphabet
#sax1=sax_via_window(combinedYearsDataFrame[1998], 2, 2)
#sax1

# %%
#sax2=sax_via_window(combinedYearsDataFrame[1999], 2, 2)
#sax2

# %%
cluster=[]
for key in pathDict:
    print(key)
    if(key[0]!=key[1]):
        if(pathDict[key]>0):
            cluster.append([key[0],key[1]])
# Out:
# (1998, 1998)
# (2007, 2011)
# (2007, 2012)
# (2007, 2013)
# (2007, 2014)
# (2007, 2015)
# (2007, 2016)
# (2007, 2017)
# (2008, 2008)
# (2008, 2009)
# (2008, 2010)
# (2008, 2011)
# (2008, 2012)
# (2008, 2013)
# (2008, 2014)
# (2008, 2015)
# (2008, 2016)
# (2008, 2017)
# (2009, 2009)
# (2009, 2010)
# (2009, 2011)
# (2009, 2012)
# (2009, 2013)
# (2009, 2014)
# (2009, 2015)
# (2009, 2016)
# (2009, 2017)
# (2010, 2010)
# (2010, 2011)
# (2010, 2012)
# (2010, 2013)
# (2010, 2014)
# (2010, 2015)
# (2010, 2016)
# (2010, 2017)
# (2011, 2011)
# (2011, 2012)
# (2011, 2013)
# (2011, 2014)
# (2011, 2015)
# (2011, 2016)
# (2011, 2017)
# (2012, 2012)
# (2012, 2013)
# (2012, 2014)
# (2012, 2015)
# (2012, 2016)
# (2012, 2017)
# (2013, 2013)
# (2013, 2014)
# (2013, 2015)
# (2013, 2016)
# (2013, 2017)
# (2014, 2014)
# (2014, 2015)
# (2014, 2016)
# (2014, 2017)
# (2015, 2015)
# (2015, 2016)
# (2015, 2017)
# (2016, 2016)
# (2016, 2017)
# (2017, 2017)

# %%
tempDF=pd.DataFrame(cluster,columns=['first','second'])

# %%
tempDF
# Out:
#     first  second
# 0    1998    1999
# 1    1998    2000
# 2    1998    2001
# 3    1998    2004
# 4    1998    2005
# 5    1998    2011
# 6    1999    2006
# 7    1999    2011
# 8    2000    2002
# 9    2000    2009
# 10   2000    2010
# 11   2000    2011
# 12   2000    2013
# 13   2000    2014
# 14   2000    2016
# 15   2000    2017
# 16   2001    2007
# 17   2003    2006
# 18   2003    2008
# 19   2003    2011
# 20   2003    2014
# 21   2003    2016
# 22   2004    2009
# 23   2004    2011
# 24   2004    2013
# 25   2004    2014
# 26   2004    2015
# 27   2004    2017
# 28   2006    2011
# 29   2006    2012
# 30   2006    2016
# 31   2007    2013
# 32   2007    2014
# 33   2007    2015
# 34   2007    2017
# 35   2008    2009
# 36   2008    2012
# 37   2008    2013
# 38   2008    2014
# 39   2008    2015
# 40   2008    2016
# 41   2008    2017
# 42   2009    2013
# 43   2009    2014
# 44   2009    2015
# 45   2009    2017
# 46   2011    2013
# 47   2011    2016
# 48   2011    2017
# 49   2013    2015
# 50   2013    2017
# 51   2014    2015
# 52   2014    2016
# 53   2014    2017
# 54   2016    2017

# %%
InCluster=set();
clust=[]
for x in range(1998,2017):
    clust.append([]);
    currArr=x-1998;
    try:
        temp=tempDF.groupby("first").get_group(x)
        temp_cluster=list(temp["second"])
        print(currArr,temp_cluster)
        for i in range(0,len(temp_cluster)):
            if(x not in InCluster):
                clust[currArr].append(x)
            if(temp_cluster[i] not in InCluster):
                clust[currArr].append(temp_cluster[i])
            InCluster.add(x)
            InCluster.add(temp_cluster[i])
    except:
        print("Not a group")
# Out:
# 0 [1999, 2000, 2001, 2004, 2005, 2011]
# 1 [2006, 2011]
# 2 [2002, 2009, 2010, 2011, 2013, 2014, 2016, 2017]
# 3 [2007]
# Not a group
# 5 [2006, 2008, 2011, 2014, 2016]
# 6 [2009, 2011, 2013, 2014, 2015, 2017]
# Not a group
# 8 [2011, 2012, 2016]
# 9 [2013, 2014, 2015, 2017]
# 10 [2009, 2012, 2013, 2014, 2015, 2016, 2017]
# 11 [2013, 2014, 2015, 2017]
# Not a group
# 13 [2013, 2016, 2017]
# Not a group
# 15 [2015, 2017]
# 16 [2015, 2016, 2017]
# Not a group
# 18 [2017]

# %%
final_clusts = [x for x in clust if x != []]

# %%
final_clusts
# Out:
# [[1998, 1999, 2000, 2001, 2004, 2005, 2011],
#  [2006],
#  [2002, 2009, 2010, 2013, 2014, 2016, 2017],
#  [2007],
#  [2003, 2008],
#  [2015],
#  [2012]]

# %% [markdown]
# ## COSINE SIMILARITY:

# %%
cosineMatrix=[]
for x in range(1998,2018):
    cosineMatrix.append([]);
    for y in range(1998,2018):
        result = 1 - spatial.distance.cosine(combinedYearsDataFrame[x], combinedYearsDataFrame[y])
        cosineMatrix[x-1998].append(result);

# %%
cosineMatrix
# Out:
# [[1.0,
#   0.37751590327724427,
#   0.19080803599650564,
#   -0.064600772579080257,
#   0.28833912526325545,
#   0.65673404475561969,
#   0.42668665419266105,
#   0.50724798607320987,
#   0.35928137296869522,
#   0.34239945915606551,
#   -0.084446030214150758,
#   0.23201746616419916,
#   0.013151786347041727,
#   0.57253814798686409,
#   -0.49013256857411847,
#   -0.047369003343376459,
#   0.018784528199568218,
#   0.22291146030158215,
#   0.2202709439766537,
#   0.13235784139973472],
#  [0.37751590327724427,
#   1.0,
#   0.75141664411527176,
#   -0.49732720409495101,
#   0.73546945244465767,
#   0.58473497514356731,
#   -0.13576580934472426,
#   -0.055553137478996373,
#   0.30896506859095385,
#   -0.2274625254378666,
#   0.39871554263855602,
#   -0.54766765039240561,
#   0.50436837940121704,
#   0.52410880100270507,
#   0.15355071799201636,
#   -0.70549410730954332,
#   -0.59196630408674311,
#   -0.33809360578443259,
#   -0.27029487589103418,
#   -0.51614111053009637],
#  [0.19080803599650564,
#   0.75141664411527176,
#   1.0,
#   -0.44337646014078347,
#   0.77345280846775155,
#   0.57527484920159833,
#   -0.22405448068665379,
#   -0.18955794198766451,
#   -0.021135886588253383,
#   -0.45744181069491185,
#   0.69523166664359914,
#   -0.75177405911724571,
#   0.57934279614385009,
#   0.42754754989995591,
#   0.32476463280778933,
#   -0.83352356263527438,
#   -0.76694036569619217,
#   -0.56246578504893785,
#   -0.54813102669981095,
#   -0.78695317231330475],
#  [-0.064600772579080257,
#   -0.49732720409495101,
#   -0.44337646014078347,
#   1.0,
#   -0.28905752048676758,
#   -0.37489661005387354,
#   0.096501723155849484,
#   0.10038461281215216,
#   -0.42836348765207233,
#   0.38077277479504645,
#   0.85237134614360277,
#   -0.58598260938047342,
#   -0.41784130271103015,
#   -0.54940727081240714,
#   1.0,
#   0.79780163238670032,
#   0.74391497331585188,
#   0.51011326178426863,
#   0.86366185866097578],
#  [0.018784528199568218,
#   -0.59196630408674311,
#   -0.76694036569619217,
#   0.1678139291826799,
#   -0.62260922899969717,
#   -0.47721541224228781,
#   0.34227113347990712,
#   0.43812003815718126,
#   0.31900377927983881,
#   0.52772658254443328,
#   -0.84026232655174216,
#   0.91185835823542349,
#   -0.64000341211878853,
#   -0.27356129443896049,
#   -0.41851900939097253,
#   0.79780163238670032,
#   1.0,
#   0.602974749083661,
#   0.8108105870519482,
#   0.9157426940474781],
#  [0.22291146030158215,
#   -0.33809360578443259,
#   -0.56246578504893785,
#   0.40773417301553505,
#   -0.11253698382904087,
#   -0.13448726561165825,
#   0.32087445628803435,
#   0.5145951289140982,
#   0.36122444854783209,
#   0.89942677376865476,
#   -0.70271726149613167,
#   0.76651089809455031,
#   -0.14648096036991953,
#   -0.058969275139170607,
#   -0.76342711248495365,
#   0.74391497331585188,
#   0.602974749083661,
#   1.0,
#   0.5762705631167192,
#   0.80879466556511304],
#  [0.2202709439766537,
#   -0.27029487589103418,
#   -0.54813102669981095,
#   -0.089674800936621057,
#   -0.33529697706527917,
#   -0.22386391517810966,
#   0.23595135236005249,
#   0.51235195512156573,
#   0.65309933653064944,
#   0.53009189049783956,
#   -0.75081748663871539,
#   0.78273541649092038,
#   -0.34094450135579146,
#   -0.030665877941293385,
#   -0.49121166275158146,
#   0.51011326178426863,
#   0.8108105870519482,
#   0.5762705631167192,
#   1.0,
#   0.81877414590650877],
#  [0.13235784139973472,
#   -0.51614111053009637,
#   -0.78695317231330475,
#   0.2977661936113446,
#   -0.48163372942747373,
#   -0.38534984302181896,
#   0.37639824868769201,
#   0.49020944230281727,
#   0.40937728177072752,
#   0.75302022093729948,
#   -0.90224584817725995,
#   0.95042473746931255,
#   -0.51391185766999015,
#   -0.18576896231639806,
#   -0.60275569557147213,
#   0.86366185866097578,
#   0.9157426940474781,
#   0.80879466556511304,
#   0.81877414590650877,
#   1.0]]

# %%
cosineMatrixDF=pd.DataFrame(cosineMatrix)
for x in range(0,len(cosineMatrixDF)):
    cosineMatrixDF.rename(columns={x:1998+x}, 
                 inplace=True)
tempList=list(cosineMatrixDF.columns)
cosineMatrixDF["year"]=tempList
cosineMatrixDF=cosineMatrixDF.set_index("year")

# %%
cosineMatrixDF
# Out:
#           1998      1999      2000      2001      2002      2003      2004  \
# year
# 1998  1.000000  0.377516  0.190808 -0.064601  0.288339  0.656734  0.426687
# 1999  0.377516  1.000000  0.751417 -0.497327  0.735469  0.584735 -0.135766
# 2000  0.190808  0.751417  1.000000 -0.443376  0.773453  0.575275 -0.224054
# 2001 -0.064601 -0.497327 -0.443376  1.000000 -0.289058 -0.374897  0.096502
# 2016  0.512352  0.653099  0.530092 -0.750817  0.782735 -0.340945 -0.030666
# 2017  0.490209  0.409377  0.753020 -0.902246  0.950425 -0.513912 -0.185769
#
#           2012      2013      2014      2015      2016      2017
# year
# 1998 -0.490133 -0.047369  0.018785  0.222911  0.220271  0.132358
# 1999  0.153551 -0.705494 -0.591966 -0.338094 -0.270295 -0.516141
# 2000  0.324765 -0.833524 -0.766940 -0.562466 -0.548131 -0.786953
# 2001 -0.216211  0.574532  0.167814  0.407734 -0.089675  0.297766
# 2002 -0.063047 -0.529820 -0.622609 -0.112537 -0.335297 -0.481634
# 2003 -0.257975 -0.497407 -0.477215 -0.134487 -0.223864 -0.385350
# 2004 -0.418771  0.293092  0.342271  0.320874  0.235951  0.376398
# 2005 -0.631835  0.354111  0.438120  0.514595  0.512352  0.490209
# 2006 -0.314035  0.024582  0.319004  0.361224  0.653099  0.409377
# 2007 -0.747185  0.669826  0.527727  0.899427  0.530092  0.753020
# 2008  0.477188 -0.774877 -0.840262 -0.702717 -0.750817 -0.902246
# 2009 -0.668379  0.852371  0.911858  0.766511  0.782735  0.950425
# 2010  0.202416 -0.585983 -0.640003 -0.146481 -0.340945 -0.513912
# 2011 -0.162252 -0.417841 -0.273561 -0.058969 -0.030666 -0.185769
# 2012  1.000000 -0.549407 -0.418519 -0.763427 -0.491212 -0.602756
# 2013 -0.549407  1.000000  0.797802  0.743915  0.510113  0.863662
# 2014 -0.418519  0.797802  1.000000  0.602975  0.810811  0.915743
# 2015 -0.763427  0.743915  0.602975  1.000000  0.576271  0.808795
# 2016 -0.491212  0.510113  0.810811  0.576271  1.000000  0.818774
# 2017 -0.602756  0.863662  0.915743  0.808795  0.818774  1.000000

# %%
cosineHashSet=set();
threshold=0.5;
cosCluster=[]
for x in range(1998,2018):
    cosCluster.append([]);
    currList=list(cosineMatrixDF[cosineMatrixDF[x]>0.5].index)
    for i in range(0,len(currList)):
        if(currList[i] not in cosineHashSet):
            cosCluster[x-1998].append(currList[i])
        cosineHashSet.add(x)
        cosineHashSet.add(currList[i])

# %%
final_cosClusts = [x for x in cosCluster if x != []]

# %%
final_cosClusts
# Out:
# [[1998, 2003, 2005, 2011],
#  [1999, 2000, 2002, 2010],
#  [2008],
#  [2001, 2013],
#  [2004],
#  [2009, 2015, 2016],
#  [2006],
#  [2007, 2014, 2017],
#  [2012]]

# %%
data = {}
for x in range(0, len(final_cosClusts)):
    key="Cluster"+str(x+1)
    data[key] = list(map(int, final_cosClusts[x]))
json_data = json.dumps(data)
json_data
# Out:
# '{"Cluster1": [1998, 2003, 2005, 2011], "Cluster2": [1999, 2000, 2002, 2010], "Cluster3": [2008], "Cluster4": [2001, 2013], "Cluster5": [2004], "Cluster6": [2009, 2015, 2016], "Cluster7": [2006], "Cluster8": [2007, 2014, 2017], "Cluster9": [2012]}'

# %%
type(final_cosClusts[x][0])
# Out:
# numpy.int64
